# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt
import random
import os
import cv2

# !pip install opendatasets --upgrade --quiet
import opendatasets as od

# %%
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop,Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
# from keras.layers.merge import concatenate
from tensorflow.keras.models import Model
from keras.preprocessing import image
from keras.layers import Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from imutils import paths
import argparse

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_url = 'https://www.kaggle.com/datasets/tawsifurrahman/covid19-radiography-database?recency=last7Days'
data_dir = '/content/COVID-19_Radiography_Dataset'

# %%
# #load training and testing dataset from output directory where the split is fixed for all models
# train_datagen=ImageDataGenerator(rescale = 1./255,
#                                    rotation_range=15,
#                                    fill_mode="nearest",
#                                    horizontal_flip = True)
# valid_datagen=ImageDataGenerator(rescale = 1./255)
# test_datagen=ImageDataGenerator(rescale = 1./255)

# training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/New_DS/output/train',
#                                                  target_size = (224, 224),
#                                                  batch_size = 64,
#                                                  class_mode = 'categorical',
#                                                  shuffle=True)
# valid_set=valid_datagen.flow_from_directory('/content/drive/MyDrive/New_DS/output/val',
#                                             target_size = (224, 224),
#                                             batch_size = 64,
#                                             class_mode = 'categorical',
#                                             shuffle = False)
# test_set=test_datagen.flow_from_directory('/content/drive/MyDrive/New_DS/output/test',
#                                             target_size = (224, 224),
#                                             batch_size = 64,
#                                             class_mode = 'categorical',
#                                             shuffle = False)

# %%
# !pip install split-folders
import splitfolders
input_folder = '/content/drive/MyDrive/Covid_DS/Covid19_Radiography Dataset'
splitfolders.ratio( input_folder,
                   output="output",seed=1337,ratio=(0.7,0.2,0.1))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: split-folders in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Copying files: 17606 files [01:21, 215.03 files/s]

# %%
#load training and testing dataset from directory
train_datagen=ImageDataGenerator(rescale = 1./255,
                                   rotation_range=15,
                                   fill_mode="nearest",
                                   horizontal_flip = True)
valid_datagen=ImageDataGenerator(rescale = 1./255)
test_datagen=ImageDataGenerator(rescale = 1./255)

training_set=train_datagen.flow_from_directory('/content/output/train',
                                                 target_size = (224, 224),
                                                 batch_size = 64,
                                                 class_mode = 'categorical',
                                                 shuffle=True)
valid_set=valid_datagen.flow_from_directory('/content/output/val',
                                            target_size = (224, 224),
                                            batch_size = 64,
                                            class_mode = 'categorical',
                                            shuffle = False)
test_set=test_datagen.flow_from_directory('/content/output/test',
                                            target_size = (224, 224),
                                            batch_size = 64,
                                            class_mode = 'categorical',
                                            shuffle = False)
# Out:
# Found 12323 images belonging to 4 classes.
# Found 3520 images belonging to 4 classes.
# Found 1763 images belonging to 4 classes.

# %%
print(training_set.class_indices)
print(valid_set.class_indices)
print(test_set.class_indices)
# Out:
# {'COVID': 0, 'Lung_Opacity': 1, 'Normal': 2, 'Viral Pneumonia': 3}
# {'COVID': 0, 'Lung_Opacity': 1, 'Normal': 2, 'Viral Pneumonia': 3}
# {'COVID': 0, 'Lung_Opacity': 1, 'Normal': 2, 'Viral Pneumonia': 3}

# %%
#visulaize data
fig, ax = plt.subplots()
ax.bar("COVID-19",3616,color="r",label="Covid19")
ax.bar("Lung_Opacity",6012 ,color="b",label="Lung_Opacity")
ax.bar("NORMAL",10192,color="m",label="Normal")
ax.bar("Viral Pneumonia",1345,color="g",label="Viral Pneumonia")
ax.legend()

# %%
#tf.keras.applications.ResNet50
from tensorflow.keras.layers import BatchNormalization
ResNet50_MODEL = Sequential()
ResNet50_MODEL.add(tf.keras.applications.ResNet50(include_top=False, pooling='avg', weights="imagenet"))
ResNet50_MODEL.add(Flatten())
ResNet50_MODEL.add(BatchNormalization())
ResNet50_MODEL.add(Dense(2048, activation='relu'))
ResNet50_MODEL.add(BatchNormalization())
ResNet50_MODEL.add(Dense(1024, activation='relu'))
ResNet50_MODEL.add(BatchNormalization())
ResNet50_MODEL.add(Dense(4, activation='softmax'))

ResNet50_MODEL.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
ResNet50_MODEL.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dense (Dense)               (None, 2048)              4196352
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 29,906,820
# Trainable params: 6,308,868
# Non-trainable params: 23,597,952
# _________________________________________________________________

# %%
tf.keras.callbacks.ReduceLROnPlateau
from keras.callbacks import LearningRateScheduler

# %%
#to avoid overfitting
early = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5)

# %%
epochs = 100
learning_rate = 0.001
decay_rate = learning_rate / epochs
optimizer_details = Adam(lr = learning_rate, decay = decay_rate)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
ResNet50_MODEL.compile(optimizer = optimizer_details, 
              loss='categorical_crossentropy',
              metrics=['accuracy','Precision','Recall'])
history = ResNet50_MODEL.fit(training_set, validation_data = valid_set, epochs=epochs, verbose=1, callbacks=[early])
# Out:
# Epoch 1/100
# 193/193 [==============================] - 200s 956ms/step - loss: 0.9086 - accuracy: 0.6959 - precision: 0.7342 - recall: 0.6329 - val_loss: 1.0596 - val_accuracy: 0.5790 - val_precision: 0.5790 - val_recall: 0.5787
# Epoch 2/100
# 193/193 [==============================] - 180s 933ms/step - loss: 0.6106 - accuracy: 0.7698 - precision: 0.7951 - recall: 0.7376 - val_loss: 0.8664 - val_accuracy: 0.6511 - val_precision: 0.7110 - val_recall: 0.5906
# Epoch 3/100
# 193/193 [==============================] - 177s 918ms/step - loss: 0.5676 - accuracy: 0.7863 - precision: 0.8091 - recall: 0.7572 - val_loss: 0.6186 - val_accuracy: 0.7412 - val_precision: 0.7658 - val_recall: 0.7014
# Epoch 4/100
# 193/193 [==============================] - 178s 921ms/step - loss: 0.5405 - accuracy: 0.7957 - precision: 0.8166 - recall: 0.7706 - val_loss: 0.5331 - val_accuracy: 0.7977 - val_precision: 0.8214 - val_recall: 0.7696
# Epoch 5/100
# 193/193 [==============================] - 178s 921ms/step - loss: 0.5268 - accuracy: 0.7991 - precision: 0.8219 - recall: 0.7772 - val_loss: 0.7812 - val_accuracy: 0.7207 - val_precision: 0.7313 - val_recall: 0.7060
# Epoch 6/100
# 193/193 [==============================] - 178s 920ms/step - loss: 0.4895 - accuracy: 0.8095 - precision: 0.8299 - recall: 0.7882 - val_loss: 0.6003 - val_accuracy: 0.7821 - val_precision: 0.8013 - val_recall: 0.7594
# Epoch 7/100
# 193/193 [==============================] - 176s 911ms/step - loss: 0.4782 - accuracy: 0.8218 - precision: 0.8390 - recall: 0.7991 - val_loss: 0.6750 - val_accuracy: 0.7548 - val_precision: 0.7725 - val_recall: 0.7401
# Epoch 8/100
# 193/193 [==============================] - 175s 909ms/step - loss: 0.4671 - accuracy: 0.8216 - precision: 0.8400 - recall: 0.8017 - val_loss: 0.4786 - val_accuracy: 0.8281 - val_precision: 0.8407 - val_recall: 0.8128
# Epoch 9/100
# 193/193 [==============================] - 176s 911ms/step - loss: 0.4515 - accuracy: 0.8295 - precision: 0.8474 - recall: 0.8121 - val_loss: 0.4654 - val_accuracy: 0.8213 - val_precision: 0.8402 - val_recall: 0.8020
# Epoch 10/100
# 193/193 [==============================] - 176s 911ms/step - loss: 0.4535 - accuracy: 0.8303 - precision: 0.8458 - recall: 0.8139 - val_loss: 0.4891 - val_accuracy: 0.8165 - val_precision: 0.8316 - val_recall: 0.7940
# Epoch 11/100
# 193/193 [==============================] - 173s 894ms/step - loss: 0.4313 - accuracy: 0.8391 - precision: 0.8534 - recall: 0.8231 - val_loss: 0.5003 - val_accuracy: 0.8131 - val_precision: 0.8279 - val_recall: 0.8023
# Epoch 12/100
# 193/193 [==============================] - 176s 911ms/step - loss: 0.4280 - accuracy: 0.8405 - precision: 0.8556 - recall: 0.8246 - val_loss: 0.4582 - val_accuracy: 0.8284 - val_precision: 0.8447 - val_recall: 0.8131
# Epoch 13/100
# 193/193 [==============================] - 176s 910ms/step - loss: 0.4125 - accuracy: 0.8475 - precision: 0.8623 - recall: 0.8311 - val_loss: 0.4812 - val_accuracy: 0.8406 - val_precision: 0.8529 - val_recall: 0.8287
# Epoch 14/100
# 193/193 [==============================] - 175s 905ms/step - loss: 0.4267 - accuracy: 0.8418 - precision: 0.8566 - recall: 0.8271 - val_loss: 0.4933 - val_accuracy: 0.8222 - val_precision: 0.8333 - val_recall: 0.8108
# Epoch 15/100
# 193/193 [==============================] - 175s 905ms/step - loss: 0.4066 - accuracy: 0.8497 - precision: 0.8652 - recall: 0.8340 - val_loss: 0.4356 - val_accuracy: 0.8432 - val_precision: 0.8538 - val_recall: 0.8310
# Epoch 16/100
# 193/193 [==============================] - 178s 924ms/step - loss: 0.3929 - accuracy: 0.8577 - precision: 0.8705 - recall: 0.8444 - val_loss: 0.4800 - val_accuracy: 0.8256 - val_precision: 0.8393 - val_recall: 0.8088
# Epoch 17/100
# 193/193 [==============================] - 178s 921ms/step - loss: 0.3862 - accuracy: 0.8551 - precision: 0.8675 - recall: 0.8407 - val_loss: 0.5285 - val_accuracy: 0.8222 - val_precision: 0.8353 - val_recall: 0.8057
# Epoch 18/100
# 193/193 [==============================] - 178s 922ms/step - loss: 0.3883 - accuracy: 0.8566 - precision: 0.8703 - recall: 0.8410 - val_loss: 0.4959 - val_accuracy: 0.8267 - val_precision: 0.8407 - val_recall: 0.8139
# Epoch 19/100
# 193/193 [==============================] - 178s 921ms/step - loss: 0.3873 - accuracy: 0.8562 - precision: 0.8687 - recall: 0.8411 - val_loss: 0.4526 - val_accuracy: 0.8420 - val_precision: 0.8534 - val_recall: 0.8318
# Epoch 20/100
# 193/193 [==============================] - 176s 911ms/step - loss: 0.3796 - accuracy: 0.8562 - precision: 0.8697 - recall: 0.8436 - val_loss: 0.4273 - val_accuracy: 0.8517 - val_precision: 0.8591 - val_recall: 0.8398
# Epoch 21/100
# 193/193 [==============================] - 177s 914ms/step - loss: 0.3627 - accuracy: 0.8673 - precision: 0.8782 - recall: 0.8560 - val_loss: 0.4478 - val_accuracy: 0.8494 - val_precision: 0.8592 - val_recall: 0.8358
# Epoch 22/100
# 193/193 [==============================] - 176s 913ms/step - loss: 0.3672 - accuracy: 0.8600 - precision: 0.8752 - recall: 0.8478 - val_loss: 0.5375 - val_accuracy: 0.8060 - val_precision: 0.8189 - val_recall: 0.7901
# Epoch 23/100
# 193/193 [==============================] - 180s 934ms/step - loss: 0.3561 - accuracy: 0.8706 - precision: 0.8814 - recall: 0.8586 - val_loss: 0.4619 - val_accuracy: 0.8415 - val_precision: 0.8528 - val_recall: 0.8327
# Epoch 24/100
# 193/193 [==============================] - 182s 940ms/step - loss: 0.3699 - accuracy: 0.8650 - precision: 0.8749 - recall: 0.8531 - val_loss: 0.4474 - val_accuracy: 0.8494 - val_precision: 0.8628 - val_recall: 0.8398
# Epoch 25/100
# 193/193 [==============================] - 182s 941ms/step - loss: 0.3351 - accuracy: 0.8762 - precision: 0.8861 - recall: 0.8662 - val_loss: 0.4186 - val_accuracy: 0.8577 - val_precision: 0.8658 - val_recall: 0.8446
# Epoch 26/100
# 193/193 [==============================] - 182s 940ms/step - loss: 0.3480 - accuracy: 0.8706 - precision: 0.8808 - recall: 0.8594 - val_loss: 0.4132 - val_accuracy: 0.8568 - val_precision: 0.8641 - val_recall: 0.8469
# Epoch 27/100
# 193/193 [==============================] - 182s 941ms/step - loss: 0.3360 - accuracy: 0.8760 - precision: 0.8868 - recall: 0.8647 - val_loss: 0.4718 - val_accuracy: 0.8381 - val_precision: 0.8499 - val_recall: 0.8284
# Epoch 28/100
# 193/193 [==============================] - 182s 941ms/step - loss: 0.3380 - accuracy: 0.8723 - precision: 0.8824 - recall: 0.8625 - val_loss: 0.5112 - val_accuracy: 0.8267 - val_precision: 0.8367 - val_recall: 0.8119
# Epoch 29/100
# 193/193 [==============================] - 181s 936ms/step - loss: 0.3289 - accuracy: 0.8779 - precision: 0.8882 - recall: 0.8692 - val_loss: 0.3796 - val_accuracy: 0.8673 - val_precision: 0.8773 - val_recall: 0.8554
# Epoch 30/100
# 193/193 [==============================] - 179s 929ms/step - loss: 0.3214 - accuracy: 0.8827 - precision: 0.8938 - recall: 0.8725 - val_loss: 0.4937 - val_accuracy: 0.8259 - val_precision: 0.8363 - val_recall: 0.8173
# Epoch 31/100
# 193/193 [==============================] - 180s 934ms/step - loss: 0.3155 - accuracy: 0.8837 - precision: 0.8937 - recall: 0.8743 - val_loss: 0.4040 - val_accuracy: 0.8648 - val_precision: 0.8747 - val_recall: 0.8568
# Epoch 32/100
# 193/193 [==============================] - 180s 934ms/step - loss: 0.3219 - accuracy: 0.8787 - precision: 0.8888 - recall: 0.8694 - val_loss: 0.4191 - val_accuracy: 0.8565 - val_precision: 0.8649 - val_recall: 0.8438
# Epoch 33/100
# 193/193 [==============================] - 180s 933ms/step - loss: 0.3103 - accuracy: 0.8834 - precision: 0.8919 - recall: 0.8734 - val_loss: 0.4129 - val_accuracy: 0.8568 - val_precision: 0.8686 - val_recall: 0.8429
# Epoch 34/100
# 193/193 [==============================] - 181s 939ms/step - loss: 0.3045 - accuracy: 0.8884 - precision: 0.8973 - recall: 0.8794 - val_loss: 0.4033 - val_accuracy: 0.8653 - val_precision: 0.8726 - val_recall: 0.8565

# %%
ResNet50_MODEL.evaluate(test_set, verbose=1)
#***model.evaluate(test_set)
# Out:
# 28/28 [==============================] - 7s 235ms/step - loss: 0.4022 - accuracy: 0.8542 - precision: 0.8666 - recall: 0.8434
# [0.4022499620914459, 0.854225754737854, 0.866550087928772, 0.8434486389160156]

# %%
ResNet50_MODEL.save('something.h5')

# %%
#Accuracy, val_acc, loss, val_loss, epoch_range
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']     #history2.history['accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs=range(len(acc))

# %%
print("accuracy: ",acc)
print("validation accuracy: ",val_acc)
print("loss: ",loss)
print("validation loss: ",val_loss)
print("epochs: ",epochs)
# Out:
# accuracy:  [0.6959344148635864, 0.7697800993919373, 0.7863345146179199, 0.7956666350364685, 0.7990748882293701, 0.8094620108604431, 0.8217966556549072, 0.8215531706809998, 0.8295058012008667, 0.8303173184394836, 0.8390814065933228, 0.8405420780181885, 0.8475208878517151, 0.8418404459953308, 0.8497118949890137, 0.8577457070350647, 0.8551489114761353, 0.856609582901001, 0.8562038540840149, 0.8562038540840149, 0.867321252822876, 0.8600178360939026, 0.8705672025680542, 0.8650491237640381, 0.8762476444244385, 0.8706483840942383, 0.8760042190551758, 0.8722713589668274, 0.8778706192970276, 0.8827396035194397, 0.8837133646011353, 0.8786821365356445, 0.8833887577056885, 0.888420045375824]
# validation accuracy:  [0.5789772868156433, 0.6511363387107849, 0.7411931753158569, 0.7977272868156433, 0.7207386493682861, 0.7821022868156433, 0.7548295259475708, 0.828125, 0.8213068246841431, 0.8164772987365723, 0.8130682110786438, 0.8284090757369995, 0.840624988079071, 0.8221591114997864, 0.8431817889213562, 0.8255681991577148, 0.8221591114997864, 0.8267045617103577, 0.8420454263687134, 0.8517045378684998, 0.8494318127632141, 0.8059659004211426, 0.8414772748947144, 0.8494318127632141, 0.8576704263687134, 0.8568181991577148, 0.8380681872367859, 0.8267045617103577, 0.8673295378684998, 0.8258522748947144, 0.8647727370262146, 0.8565340638160706, 0.8568181991577148, 0.8653408885002136]
# loss:  [0.9086186289787292, 0.610634446144104, 0.5675574541091919, 0.5405066609382629, 0.5267651677131653, 0.4894545078277588, 0.47821900248527527, 0.46713149547576904, 0.4514666795730591, 0.4534720480442047, 0.4312901496887207, 0.42798662185668945, 0.4124642014503479, 0.4267345666885376, 0.40659263730049133, 0.3929429352283478, 0.38620609045028687, 0.38831305503845215, 0.38729128241539, 0.37961694598197937, 0.362722247838974, 0.36722517013549805, 0.35605382919311523, 0.3698504865169525, 0.33506423234939575, 0.3480248749256134, 0.3359936773777008, 0.3379952311515808, 0.3289458155632019, 0.32144150137901306, 0.31552526354789734, 0.32192105054855347, 0.3102814257144928, 0.30447185039520264]
# validation loss:  [1.059570074081421, 0.8663942217826843, 0.6186344623565674, 0.5330933332443237, 0.7811869978904724, 0.6003289222717285, 0.6750203967094421, 0.4786124527454376, 0.4654012620449066, 0.48906826972961426, 0.5002991557121277, 0.4582061767578125, 0.48116686940193176, 0.49328404664993286, 0.4355795979499817, 0.48004862666130066, 0.5284817814826965, 0.495895117521286, 0.4525623023509979, 0.4272787868976593, 0.4477938115596771, 0.5374560356140137, 0.4618604779243469, 0.44744062423706055, 0.4185633659362793, 0.4132280647754669, 0.4718402028083801, 0.5111572742462158, 0.3795885741710663, 0.49365830421447754, 0.40396562218666077, 0.4190897047519684, 0.412881076335907, 0.4033445417881012]
# epochs:  range(0, 34)

# %%
#plot training nad validation accuracy
plt.plot(epochs,acc,label='Training_acc',color='blue')
plt.plot(epochs,val_acc,label='Validation_acc',color='red')
plt.legend()
plt.title("Training and Validation Accuracy")
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#training and validation loss
plt.plot(epochs,loss,label='Training_loss',color='blue')
plt.plot(epochs,val_loss,label='Validation_loss',color='red')
plt.legend()
plt.title("Training and Validation loss")
# Out:
# Text(0.5, 1.0, 'Training and Validation loss')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

train_precision=history.history['precision']
val_precision=history.history['val_precision']

train_recall=history.history['recall']
val_recall=history.history['val_recall']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, train_precision, 'r', label='Training precision')
plt.plot(epochs, val_precision, 'b', label='Validation precision')
plt.title('Training and validation precision')
plt.legend()
plt.figure()

plt.plot(epochs, train_recall, 'r', label='Training recall')
plt.plot(epochs, val_recall, 'b', label='Validation recall')
plt.title('Training and validation recall')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
#model history
import pandas as pd
loss_df = pd.DataFrame(ResNet50_MODEL.history.history)
loss_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#prediction on test data
predictions = np.argmax(ResNet50_MODEL.predict(test_set), axis = -1)
# Out:
# 28/28 [==============================] - 8s 239ms/step

# %%
#classification report
print(classification_report(test_set.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       362
#            1       0.73      0.66      0.69       246
#            2       0.90      0.88      0.89      1020
#            3       0.79      0.92      0.85       135
#
#     accuracy                           0.85      1763
#    macro avg       0.81      0.84      0.82      1763
# weighted avg       0.85      0.85      0.85      1763

# %%
# compute the confusion matrix and and use it to derive the raw
# accuracy, sensitivity, and specificity
cm = confusion_matrix(test_set.classes, predictions)
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])

# %%
import seaborn as sns
print(confusion_matrix(test_set.classes,predictions))
sns.heatmap(confusion_matrix(test_set.classes,predictions), annot = True)
# show the sensitivity, and specificity
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# [[322   8  31   1]
#  [ 19 163  64   0]
#  [ 41  50 897  32]
#  [  4   3   4 124]]
# sensitivity: 0.9758
# specificity: 0.8956

# %%
from numpy import sqrt

# %%
G_Mean = sqrt(sensitivity * specificity)
print("G_Mean: ", G_Mean)
# Out:
# G_Mean:  0.9348223220980412

# %%
True_Positive_Rate = cm[0, 0] / (cm[0, 0] + cm[0, 1])
False_Positive_Rate = cm[1, 0] / (cm[1, 0] + cm[1, 1])

# %%
print("True_Positive_Rate: {:.4f}".format(True_Positive_Rate))
print("False_Positive_Rate: {:.4f}".format(False_Positive_Rate))
# Out:
# True_Positive_Rate: 0.9758
# False_Positive_Rate: 0.1044

# %% [markdown]
# # **ROC**

# %%
print(test_set)
print(predictions)
# Out:
# <keras.preprocessing.image.DirectoryIterator object at 0x7f145e34a350>
# [0 0 0 ... 3 3 3]

# %%
testsetTo = np.concatenate([test_set.next()[1] for i in range(test_set.__len__())])
print(testsetTo.shape)
# Out:
# (1763, 4)

# %%
from scipy import interp
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
#ROC-AUC Curve
# Learn to predict each class against the other
n_classes = 4 
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
thresh = dict()
roc_auc = dict()
lw = 2 
for i in range(n_classes):
    fpr[i], tpr[i], thresh[i] = roc_curve(np.argmax(testsetTo, axis=1), predictions, pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], thresh[i] = roc_curve(np.argmax(testsetTo, axis=1), predictions, pos_label=i) 
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# Process of plotting roc-auc curve belonging to all classes.

from itertools import cycle
roc_auc_scores = []
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['red', 'darkorange', 'cornflowerblue', 'aqua'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
    roc_auc_scores.append(roc_auc[i])

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve to each class')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   # This is added back by InteractiveShellApp.init_path()
